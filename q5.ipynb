# %% [markdown]
# Iterator: object that let you access elements one by one.
#
# It has 2 methods:
# __iter__()
# __next__()

# %%
nums = [10,20,30,50]

it = iter(nums)

print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 10
# 20
# 30
# 50
