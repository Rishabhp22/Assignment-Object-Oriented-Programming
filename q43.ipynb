# %%
class Parent:
    def show(self):
        print("This is parent method")

class Child(Parent):
    def show(self):
        print("THis is child method")

obj = Child()
obj.show()
# Out:
# THis is child method
