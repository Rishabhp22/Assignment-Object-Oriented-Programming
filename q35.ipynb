# %%
class Animal:
    def make_sound(self):
        print("Generic animal sound")

class Dog(Animal):
    def make_sound(slef):
        print("Woof!")

class GermanShepherd(Dog):
    def make_sound(self):
        print("Bark!")

d = GermanShepherd()
d.make_sound()
# Out:
# Bark!
