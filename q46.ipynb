# %% [markdown]
# Python supports polymorphism through duck typing by allowing objects of different classes to be treated the same if they have similar methods. The type of object is not checked; instead, Python checks whether the required method exists.
