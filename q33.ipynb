# %% [markdown]
# It is method that elp to use the same define propert in to the child class with the same name and define the child class property.

# %%
class Animal:
    def move(self):
        print("Animal moves")

class Dog(Animal):
    def move(self):
        print("Dog runs")

d = Dog()
d.move()
# Out:
# Dog runs
