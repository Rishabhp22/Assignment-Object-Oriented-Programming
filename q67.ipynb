# %% [markdown]
# What is a Getter?
#
# 👉 A getter is a method used to access (read) the value of a private attribute of a class.

# %%
class Student:
    def __init__(self, name):
        self.__name = name   # private variable

    def get_name(self):
        return self.__name


s = Student("Rishabh")
print(s.get_name())
# Out:
# Rishabh
