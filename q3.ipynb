# %% [markdown]
# print():
#
# only display output on screen.
# value is not saved.
# fuction returns none.

# %%
def add(a,b):
    print(a+b)

result = add(5,6)
print(result)
# Out:
# 11
# None

# %% [markdown]
# return:
#
# sends value back from fuction.
# Value can be stored.

# %%
def add(a,b):
    return a+b

result = add(5,6)
print(result)
# Out:
# 11
