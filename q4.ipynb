# %% [markdown]
# *args:
#
# allow fuction to take multiple positional arguments.

# %%
def add(*args):
    return sum(args)
print(add(1,2,3,4,5))
# Out:
# 15

# %% [markdown]
# **kwargs:
# allow fuction to take multiple keyword argumnet.

# %%
def show(**kwargs):
    print(kwargs)

show(name="Rishabh", age= 20)
# Out:
# {'name': 'Rishabh', 'age': 20}
